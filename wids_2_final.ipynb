# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import gc 
import tqdm
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 100)
pd.set_option('display.max_rows', 200)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv(r'train.csv')
test = pd.read_csv(r'test.csv')
submission = pd.read_csv(r'solution_template.csv')

# %%
train = train.drop('patient_id', axis=1)
test = test.drop('patient_id', axis=1)

df = pd.concat([train, test], axis=0)

df.columns = df.columns.str.replace(' ', '_', regex=False)
df.columns = df.columns.str.replace('-', '_', regex=False)

# %%
df.drop(columns=['metastatic_first_novel_treatment_type', 'metastatic_first_novel_treatment'], inplace=True)

# %%
dolu_degerler_sozlugu = df.dropna(subset=['patient_state', 'Division', 'Region']).drop_duplicates('patient_zip3').set_index('patient_zip3')[['patient_state', 'Division', 'Region']].to_dict('index')

# Boş değerleri doldurun
for index, row in df.iterrows():
    if pd.isna(row['patient_state']) or pd.isna(row['Division']) or pd.isna(row['Region']):
        if row['patient_zip3'] in dolu_degerler_sozlugu:
            df.at[index, 'patient_state'] = dolu_degerler_sozlugu[row['patient_zip3']]['patient_state']
            df.at[index, 'Division'] = dolu_degerler_sozlugu[row['patient_zip3']]['Division']
            df.at[index, 'Region'] = dolu_degerler_sozlugu[row['patient_zip3']]['Region']

# %%
# Average ile başlayan sütunları bul
average_columns = [col for col in df.columns if col.startswith('Average')]

# Eksik değerleri patient_state ortalamaları ile doldur
for col in average_columns:
    df[col] = df.groupby('patient_state')[col].transform(lambda x: x.fillna(x.mean()))

# %%
# Male codes to female 
df['breast_cancer_diagnosis_code'] = df['breast_cancer_diagnosis_code'].replace({
    'C50122':'C50112', 'C50221':'C50211', 'C50421':'C50411', 'C509':'C5091', 'C50922':'C50912', 'C5021':'C50219'
})

# Fix bad zip 
df['patient_state'] = np.where(df['patient_zip3'] == 630, 'MO', np.where(df['patient_zip3'] == 864, 'AZ', df['patient_state']))

# %%
df['payer_type'] = df['payer_type'].fillna('Unknown')

# %%
df['bmi_missing'] = df['bmi'].isna().astype(int)

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_cols = df.select_dtypes(include=numerics).columns.drop('metastatic_diagnosis_period')

# 'metastatic_diagnosis_period' hariç numerik sütunlardaki eksik değerleri doldur
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# ### PCA

# %%
age_columns = ['age_under_10', 'age_10_to_19', 'age_20s', 'age_30s', 'age_40s', 'age_50s', 'age_60s', 'age_70s', 'age_over_80']
income_columns = ['income_household_under_5','income_household_5_to_10','income_household_10_to_15','income_household_15_to_20','income_household_20_to_25',
               'income_household_25_to_35','income_household_35_to_50','income_household_50_to_75','income_household_75_to_100','income_household_100_to_150',
               'income_household_150_over']
education_columns = ['education_less_highschool', 'education_highschool', 'education_some_college', 'education_bachelors', 'education_graduate', 'education_college_or_above']
race_columns = ['race_white', 'race_black', 'race_asian', 'race_native', 'race_pacific', 'race_other', 'race_multiple', 'hispanic']
difficulties_columns = ['disabled', 'poverty', 'limited_english', 'commute_time', 'health_uninsured', 'veteran']
workforce_columns = ['labor_force_participation', 'unemployment_rate', 'self_employed', 'farmer']
marital_status = [ 'married', 'divorced', 'never_married', 'widowed']

to_pca_cols = age_columns + income_columns + education_columns + race_columns + difficulties_columns + workforce_columns + marital_status

pca_data = df[to_pca_cols]

if True:
    # Verileri ölçeklendirme
    scaler = StandardScaler()
    scaled_pca_data = scaler.fit_transform(pca_data)

    # PCA modelini oluşturma ve eğitme
    pca = PCA(n_components=2, random_state=47)  # 2 ana bileşen
    principal_components = pca.fit_transform(scaled_pca_data)

    # Ana bileşenleri DataFrame'e ekleme
    df['PCA_1'] = principal_components[:, 0]
    df['PCA_2'] = principal_components[:, 1]

    #Average cols PCA
    average_columns = [col for col in df.columns if col.startswith('Average')]

    average_data = df[average_columns]

    # Verileri ölçeklendirme
    scaler = StandardScaler()
    scaled_average_data = scaler.fit_transform(average_data)

    # PCA modelini oluşturma ve eğitme
    pca = PCA(n_components=2, random_state=77)  # 2 ana bileşen
    principal_components = pca.fit_transform(scaled_average_data)

    # Ana bileşenleri DataFrame'e ekleme
    df['PCA_AVG_1'] = principal_components[:, 0]
    df['PCA_AVG_2'] = principal_components[:, 1]

if False:
    pca_data = df[to_pca_cols]

    # Verileri ölçeklendirme
    scaler = StandardScaler()
    scaled_pca_data = scaler.fit_transform(pca_data)

    # t-SNE modelini oluşturma ve eğitme
    tsne = TSNE(n_components=2, learning_rate='auto', init='random', random_state=6)
    tsne_components = tsne.fit_transform(scaled_pca_data)

    # t-SNE bileşenlerini DataFrame'e ekleme
    df['TSNE_1'] = tsne_components[:, 0]
    df['TSNE_2'] = tsne_components[:, 1]

    #Average cols TSNE
    average_columns = [col for col in df.columns if col.startswith('Average')]

    average_data = df[average_columns]

    # Verileri ölçeklendirme
    scaler = StandardScaler()
    scaled_average_data = scaler.fit_transform(average_data)

    tsne = TSNE(n_components=2, learning_rate='auto', init='random', random_state=6)
    tsne_components = tsne.fit_transform(scaled_average_data)

    # Ana bileşenleri DataFrame'e ekleme
    df['TSNE_AVG_1'] = tsne_components[:, 0]
    df['TSNE_AVG_2'] = tsne_components[:, 1]

# %%
# En iyi random_state'i bulmak için değişken
best_random_state = None
best_explained_variance = 0

# Farklı random_state değerleri üzerinde deneme
for random_state in range(0, 100):
    pca = PCA(n_components=2, random_state=random_state)
    principal_components = pca.fit_transform(scaled_average_data)
    explained_variance = np.sum(pca.explained_variance_ratio_)
    
    if explained_variance > best_explained_variance:
        best_explained_variance = explained_variance
        best_random_state = random_state

print(f"En iyi random_state: {best_random_state} ile açıklanan varyans oranı: {best_explained_variance}")
# Out:
# En iyi random_state: 77 ile açıklanan varyans oranı: 0.9410977030599198

# %% [markdown]
# ### breast_cancer_diagnosis_desc

# %%
def group_descriptions(desc):
    if 'unspecified' in desc or 'unsp site of' in desc:
        return 'unspecified'
    if 'upper-outer quadrant of' in desc:
        return 'upper-outer quadrant of'
    if 'central' in desc:
        return 'central'
    if 'ovrlp sites of' in desc or 'overlapping' in desc:
        return 'overlapping'
    if 'nipple and areola' in desc:
        return 'nipple and areola'
    if 'upper-inner' in desc:
        return 'upper-inner'
    if 'lower-outer' in desc:
        return 'lower-outer'
    if 'lower-inner' in desc:
        return 'lower-inner'
    if 'axillary tail' in desc:
        return 'axillary tail'
    return desc  
# Uygulama
df['breast_cancer_diagnosis_desc'] = df['breast_cancer_diagnosis_desc'].apply(group_descriptions)

# %%
df['age_group'] = pd.cut(df['patient_age'], right=False, bins=[0, 30, 40, 50, 60, 70, 80, 90, np.inf], labels=[0,1,2,3,4,5,6,7]).astype(int)
df['icd_9'] = df['breast_cancer_diagnosis_code'].str.startswith('17').astype(int)

# %%
# ICD-10 kodlarını ICD-9 kodlarına eşleştiren bir harita
icd10_to_icd9 = {
    'C509': '1749', 'C508': '1748', 'C504': '1744', 'C501': '1741', 'C505': '1745', 'C502': '1742', 
    'C503': '1743', 'C506': '1746', 'C7981': '19881', 'C500': '1740'
}

# Eşleştirme fonksiyonu
def map_icd10_to_icd9(code):
    # ICD-10 kodlarının ilk üç karakterini kullanarak eşleştirme yapıyoruz
    icd10_prefix = code[:4]
    if icd10_prefix in icd10_to_icd9:
        return icd10_to_icd9[icd10_prefix]
    else:
        return code

# Yeni sütunu oluşturma
df['icd9_feat'] = df['breast_cancer_diagnosis_code'].apply(map_icd10_to_icd9)

# %%
df.icd9_feat.unique()
# Out:
# array(['1749', '1744', '1748', '1742', '1740', '1741', '1743', '1745',
#        '19881', '1746'], dtype=object)

# %%
df['patient_zip3'] = df['patient_zip3'].astype('category')

# %%
# 'metastatic_diagnosis_period' sütununda değerleri olanları 'train' DataFrame'ine ayır
train = df[df['metastatic_diagnosis_period'].notnull()]
train.reset_index(inplace=True, drop=True)

# 'metastatic_diagnosis_period' sütununda değerleri olmayanları 'test' DataFrame'ine ayır
test = df[df['metastatic_diagnosis_period'].isnull()]
test.drop('metastatic_diagnosis_period', axis=1, inplace=True)
test.reset_index(inplace=True, drop=True)

# %% [markdown]
# ### Feature Selection

# %%
train = train[['icd_9', 'patient_age', 'breast_cancer_diagnosis_desc',
               'metastatic_cancer_diagnosis_code', 'patient_state', 'payer_type', 
               'PCA_AVG_2', 'Region', 'metastatic_diagnosis_period']]

test = test[['icd_9', 'patient_age', 'breast_cancer_diagnosis_desc',
             'metastatic_cancer_diagnosis_code', 'patient_state', 'payer_type',
             'PCA_AVG_2', 'Region']]

# 'PCA_1', 'PCA_2', 'PCA_AVG_1', 'PCA_AVG_2', 'Region', 'TSNE_1', 'TSNE_2', 'TSNE_AVG_1', 'TSNE_AVG_2', 'bmi_missing', 'age_group', 'icd_9'

# %%
# %%time
from autogluon.tabular import TabularDataset, TabularPredictor

time_limit = 3600*10

automl = TabularPredictor(label='metastatic_diagnosis_period', problem_type='regression',
                          eval_metric='root_mean_squared_error'
                          )

automl.fit(train, presets='medium_quality', time_limit=time_limit, num_bag_folds=5, num_bag_sets=0, num_stack_levels=1, dynamic_stacking=True, 
            included_model_types=['XGB', 'CAT', 'XT', 'RF', 'GBM'], ag_args_fit={'num_gpus': 1, 'num_cpus': 8},
            hyperparameters = {
              'GBM': [
              # #     {'max_depth': 8, 'n_estimators': 100000, 'feature_fraction': 0.6},
              # #     {'max_depth': 7, 'n_estimators': 100000, 'feature_fraction': 0.6},
                  {'max_depth': 6, 'n_estimators': 100000},
                  {'max_depth': 5, 'n_estimators': 100000},
                  {'max_depth': 4, 'n_estimators': 100000},
                  {'max_depth': 3, 'n_estimators': 100000},
                  {'max_depth': 2, 'n_estimators': 100000},
              ],
              'XGB': [
                  # {'max_depth': 8, 'n_estimators': 100000, 'feature_fraction': 0.6},
                  # {'max_depth': 7, 'n_estimators': 100000, 'feature_fraction': 0.6},
                  {'max_depth': 6, 'n_estimators': 100000},
                  {'max_depth': 5, 'n_estimators': 100000},
                  {'max_depth': 4, 'n_estimators': 100000},
                  {'max_depth': 3, 'n_estimators': 100000},
                  {'max_depth': 2, 'n_estimators': 100000},
              ],
              'CAT': [
                  # {'depth': 8, 'iterations': 100000},
                  # {'depth': 7, 'iterations': 100000},
                  {'depth': 6, 'iterations': 100000},
                  {'depth': 5, 'iterations': 100000},
                  {'depth': 4, 'iterations': 100000},
                  {'depth': 3, 'iterations': 100000},
                  {'depth': 2, 'iterations': 100000},
              ],
              'XT': [
                  # {'max_depth': 8},
                  # {'max_depth': 7},
                  {'max_depth': 6},
                  {'max_depth': 5},
                  {'max_depth': 4},
                  {'max_depth': 3},
                  {'max_depth': 2},
              ],
              'RF': [
                  # {'max_depth': 8},
                  # {'max_depth': 7},
                  {'max_depth': 6},
                  {'max_depth': 5},
                  {'max_depth': 4},
                  {'max_depth': 3},
                  {'max_depth': 2},
              ],
            #   'KNN': [
            #       {'n_neighbors': 30},
            #       {'n_neighbors': 60},
            #       {'n_neighbors': 100},
            #   ],
            #   'LR': [
            #       {},  # Boş dictionary default değerleri kullanır
            #   ]
          },
            keep_only_best = False
          )
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240603_094536"
# Presets specified: ['medium_quality']
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 36000 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240603_094536\ds_sub_fit\sub_fit_ho.
# Beginning AutoGluon training ... Time limit = 9000s
# AutoGluon will save models to "AutogluonModels\ag-20240603_094536\ds_sub_fit\sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.1.1b20240426
# Python Version:     3.10.10
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          12
# Memory Avail:       7.28 GB / 15.42 GB (47.2%)
# Disk Space Avail:   551.11 GB / 931.51 GB (59.2%)
# ===================================================
# Train Data Rows:    11709
# Train Data Columns: 8
# Label Column:       metastatic_diagnosis_period
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7463.65 MB
# 	Train Data (Original)  Memory Usage: 3.82 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 1 | ['PCA_AVG_2']
# 		('int', [])    : 2 | ['icd_9', 'patient_age']
# 		('object', []) : 5 | ['breast_cancer_diagnosis_desc', 'metastatic_cancer_diagnosis_code', 'patient_state', 'payer_type', 'Region']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 5 | ['breast_cancer_diagnosis_desc', 'metastatic_cancer_diagnosis_code', 'patient_state', 'payer_type', 'Region']
# 		('float', [])     : 1 | ['PCA_AVG_2']
# 		('int', [])       : 1 | ['patient_age']
# 		('int', ['bool']) : 1 | ['icd_9']
# 	0.1s = Fit runtime
# 	8 features in original data used to generate 8 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.25 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.13s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (25 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'GBM': [{'max_depth': 6, 'n_estimators': 100000}, {'max_depth': 5, 'n_estimators': 100000}, {'max_depth': 4, 'n_estimators': 100000}],
# 	'XGB': [{'max_depth': 6, 'n_estimators': 100000}, {'max_depth': 5, 'n_estimators': 100000}, {'max_depth': 4, 'n_estimators': 100000}],
# 	'CAT': [{'depth': 6, 'iterations': 100000}, {'depth': 5, 'iterations': 100000}, {'depth': 4, 'iterations': 100000}],
# 	'XT': [{'max_depth': 6}, {'max_depth': 5}, {'max_depth': 4}],
# 	'RF': [{'max_depth': 6}, {'max_depth': 5}, {'max_depth': 4}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Included models: ['XGB', 'CAT', 'XT', 'RF', 'GBM'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 25 L1 models ...
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 5998.41s of the 8999.87s of remaining time.
# Will use sequential fold fitting strategy because import of ray failed. Reason: ray==2.6.3 detected. 2.10.0 <= ray < 2.11.0 is required. You can use pip to install certain version of ray `pip install ray==2.10.0`
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-82.4966	 = Validation score   (-root_mean_squared_error)
# 	13.34s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_2_BAG_L1 ... Training model for up to 5978.66s of the 8980.11s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-82.4163	 = Validation score   (-root_mean_squared_error)
# 	10.53s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_3_BAG_L1 ... Training model for up to 5967.9s of the 8969.36s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-82.2605	 = Validation score   (-root_mean_squared_error)
# 	9.66s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_4_BAG_L1 ... Training model for up to 5958.12s of the 8959.57s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-82.1771	 = Validation score   (-root_mean_squared_error)
# 	6.36s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_5_BAG_L1 ... Training model for up to 5951.62s of the 8953.07s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-82.2477	 = Validation score   (-root_mean_squared_error)
# 	6.07s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForest_BAG_L1 ... Training model for up to 5945.36s of the 8946.81s of remaining time.
# 	-82.3959	 = Validation score   (-root_mean_squared_error)
# 	0.94s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: RandomForest_2_BAG_L1 ... Training model for up to 5944.03s of the 8945.49s of remaining time.
# 	-82.5281	 = Validation score   (-root_mean_squared_error)
# 	0.76s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: RandomForest_3_BAG_L1 ... Training model for up to 5942.91s of the 8944.36s of remaining time.
# 	-82.7453	 = Validation score   (-root_mean_squared_error)
# 	0.71s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: RandomForest_4_BAG_L1 ... Training model for up to 5941.87s of the 8943.32s of remaining time.
# 	-83.0445	 = Validation score   (-root_mean_squared_error)
# 	0.69s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForest_5_BAG_L1 ... Training model for up to 5940.87s of the 8942.32s of remaining time.
# 	-83.3045	 = Validation score   (-root_mean_squared_error)
# 	0.62s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 5939.98s of the 8941.43s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-82.1058	 = Validation score   (-root_mean_squared_error)
# 	108.56s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost_2_BAG_L1 ... Training model for up to 5831.3s of the 8832.75s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-82.1872	 = Validation score   (-root_mean_squared_error)
# 	89.49s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_3_BAG_L1 ... Training model for up to 5741.73s of the 8743.18s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-82.3472	 = Validation score   (-root_mean_squared_error)
# 	76.65s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_4_BAG_L1 ... Training model for up to 5664.91s of the 8666.36s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-82.2529	 = Validation score   (-root_mean_squared_error)
# 	93.64s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatBoost_5_BAG_L1 ... Training model for up to 5571.19s of the 8572.64s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-82.4461	 = Validation score   (-root_mean_squared_error)
# 	59.14s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: ExtraTrees_BAG_L1 ... Training model for up to 5511.98s of the 8513.43s of remaining time.
# 	-82.674	 = Validation score   (-root_mean_squared_error)
# 	0.59s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: ExtraTrees_2_BAG_L1 ... Training model for up to 5511.08s of the 8512.53s of remaining time.
# 	-82.8506	 = Validation score   (-root_mean_squared_error)
# 	0.6s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: ExtraTrees_3_BAG_L1 ... Training model for up to 5510.16s of the 8511.61s of remaining time.
# 	-83.0218	 = Validation score   (-root_mean_squared_error)
# 	0.59s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: ExtraTrees_4_BAG_L1 ... Training model for up to 5509.27s of the 8510.72s of remaining time.
# 	-83.2084	 = Validation score   (-root_mean_squared_error)
# 	0.63s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: ExtraTrees_5_BAG_L1 ... Training model for up to 5508.32s of the 8509.77s of remaining time.
# 	-83.4069	 = Validation score   (-root_mean_squared_error)
# 	0.65s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 5507.38s of the 8508.83s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-82.5137	 = Validation score   (-root_mean_squared_error)
# 	12.91s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_2_BAG_L1 ... Training model for up to 5494.21s of the 8495.67s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-82.3838	 = Validation score   (-root_mean_squared_error)
# 	12.27s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: XGBoost_3_BAG_L1 ... Training model for up to 5481.81s of the 8483.26s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-82.3275	 = Validation score   (-root_mean_squared_error)
# 	11.93s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_4_BAG_L1 ... Training model for up to 5469.73s of the 8471.18s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-82.332	 = Validation score   (-root_mean_squared_error)
# 	11.53s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: XGBoost_5_BAG_L1 ... Training model for up to 5458.06s of the 8459.51s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-82.4098	 = Validation score   (-root_mean_squared_error)
# 	13.05s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 599.84s of the 8446.14s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.5, 'LightGBM_3_BAG_L1': 0.25, 'LightGBM_4_BAG_L1': 0.167, 'RandomForest_BAG_L1': 0.083}
# 	-81.9422	 = Validation score   (-root_mean_squared_error)
# 	0.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Included models: ['XGB', 'CAT', 'XT', 'RF', 'GBM'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 25 L2 models ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 8446.07s of the 8446.04s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-81.5855	 = Validation score   (-root_mean_squared_error)
# 	13.23s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_2_BAG_L2 ... Training model for up to 8432.71s of the 8432.68s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-81.5716	 = Validation score   (-root_mean_squared_error)
# 	10.73s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_3_BAG_L2 ... Training model for up to 8421.85s of the 8421.82s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-81.668	 = Validation score   (-root_mean_squared_error)
# 	8.61s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_4_BAG_L2 ... Training model for up to 8412.96s of the 8412.93s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-81.651	 = Validation score   (-root_mean_squared_error)
# 	6.83s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_5_BAG_L2 ... Training model for up to 8405.88s of the 8405.85s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# [1000]	valid_set's rmse: 81.173
# [2000]	valid_set's rmse: 81.248
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# [1000]	valid_set's rmse: 83.7032
# 	-81.5422	 = Validation score   (-root_mean_squared_error)
# 	8.32s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForest_BAG_L2 ... Training model for up to 8397.34s of the 8397.3s of remaining time.
# 	-81.4593	 = Validation score   (-root_mean_squared_error)
# 	4.72s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: RandomForest_2_BAG_L2 ... Training model for up to 8392.24s of the 8392.21s of remaining time.
# 	-81.5675	 = Validation score   (-root_mean_squared_error)
# 	4.03s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: RandomForest_3_BAG_L2 ... Training model for up to 8387.82s of the 8387.79s of remaining time.
# 	-81.6761	 = Validation score   (-root_mean_squared_error)
# 	3.28s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: RandomForest_4_BAG_L2 ... Training model for up to 8384.11s of the 8384.08s of remaining time.
# 	-81.8844	 = Validation score   (-root_mean_squared_error)
# 	2.57s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: RandomForest_5_BAG_L2 ... Training model for up to 8381.15s of the 8381.12s of remaining time.
# 	-82.1609	 = Validation score   (-root_mean_squared_error)
# 	1.81s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 8378.91s of the 8378.88s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.4219	 = Validation score   (-root_mean_squared_error)
# 	99.28s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_2_BAG_L2 ... Training model for up to 8279.52s of the 8279.49s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.4332	 = Validation score   (-root_mean_squared_error)
# 	79.78s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_3_BAG_L2 ... Training model for up to 8199.63s of the 8199.6s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.4782	 = Validation score   (-root_mean_squared_error)
# 	64.85s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_4_BAG_L2 ... Training model for up to 8134.59s of the 8134.55s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.4857	 = Validation score   (-root_mean_squared_error)
# 	54.66s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_5_BAG_L2 ... Training model for up to 8079.82s of the 8079.79s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.5608	 = Validation score   (-root_mean_squared_error)
# 	51.1s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTrees_BAG_L2 ... Training model for up to 8028.52s of the 8028.48s of remaining time.
# 	-81.6822	 = Validation score   (-root_mean_squared_error)
# 	0.73s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: ExtraTrees_2_BAG_L2 ... Training model for up to 8027.38s of the 8027.35s of remaining time.
# 	-81.7669	 = Validation score   (-root_mean_squared_error)
# 	0.72s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: ExtraTrees_3_BAG_L2 ... Training model for up to 8026.27s of the 8026.24s of remaining time.
# 	-81.8628	 = Validation score   (-root_mean_squared_error)
# 	0.65s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: ExtraTrees_4_BAG_L2 ... Training model for up to 8025.26s of the 8025.22s of remaining time.
# 	-81.9965	 = Validation score   (-root_mean_squared_error)
# 	0.66s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: ExtraTrees_5_BAG_L2 ... Training model for up to 8024.23s of the 8024.2s of remaining time.
# 	-82.2887	 = Validation score   (-root_mean_squared_error)
# 	0.65s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 8023.22s of the 8023.19s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.7432	 = Validation score   (-root_mean_squared_error)
# 	17.3s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_2_BAG_L2 ... Training model for up to 8005.74s of the 8005.7s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.5724	 = Validation score   (-root_mean_squared_error)
# 	13.9s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_3_BAG_L2 ... Training model for up to 7991.59s of the 7991.56s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.5149	 = Validation score   (-root_mean_squared_error)
# 	12.35s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_4_BAG_L2 ... Training model for up to 7979.05s of the 7979.02s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.6024	 = Validation score   (-root_mean_squared_error)
# 	11.5s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: XGBoost_5_BAG_L2 ... Training model for up to 7967.34s of the 7967.3s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.5363	 = Validation score   (-root_mean_squared_error)
# 	14.2s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 844.61s of the 7952.65s of remaining time.
# 	Ensemble Weights: {'LightGBM_5_BAG_L2': 0.238, 'RandomForest_BAG_L2': 0.19, 'XGBoost_BAG_L2': 0.19, 'LightGBM_BAG_L2': 0.143, 'CatBoost_BAG_L2': 0.143, 'CatBoost_2_BAG_L2': 0.048, 'XGBoost_5_BAG_L2': 0.048}
# 	-81.2018	 = Validation score   (-root_mean_squared_error)
# 	0.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1047.43s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240603_094536\ds_sub_fit\sub_fit_ho")
# Leaderboard on holdout data from dynamic stacking:
#                     model  holdout_score  score_val              eval_metric  pred_time_test  pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0        XGBoost_4_BAG_L2        -79.032    -81.602  root_mean_squared_error           3.189          3.255   553.416                    0.203                   0.117             11.503            2       True         50
# 1        XGBoost_3_BAG_L2        -79.090    -81.515  root_mean_squared_error           3.180          3.221   554.268                    0.194                   0.083             12.354            2       True         49
# 2     WeightedEnsemble_L3        -79.095    -81.202  root_mean_squared_error           4.050          3.817   778.792                    0.012                   0.000              0.048            3       True         52
# 3     ExtraTrees_3_BAG_L2        -79.113    -81.863  root_mean_squared_error           3.083          3.399   542.562                    0.097                   0.261              0.649            2       True         44
# 4       ExtraTrees_BAG_L2        -79.116    -81.682  root_mean_squared_error           3.086          3.432   542.639                    0.100                   0.294              0.726            2       True         42
# 5   RandomForest_4_BAG_L2        -79.119    -81.884  root_mean_squared_error           3.191          3.414   544.488                    0.206                   0.276              2.574            2       True         35
# 6     ExtraTrees_2_BAG_L2        -79.119    -81.767  root_mean_squared_error           3.081          3.422   542.635                    0.095                   0.284              0.722            2       True         43
# 7       LightGBM_5_BAG_L2        -79.122    -81.542  root_mean_squared_error           3.173          3.217   550.233                    0.187                   0.079              8.320            2       True         31
# 8       CatBoost_4_BAG_L2        -79.133    -81.486  root_mean_squared_error           3.064          3.177   596.577                    0.078                   0.039             54.663            2       True         40
# 9   RandomForest_3_BAG_L2        -79.144    -81.676  root_mean_squared_error           3.078          3.418   545.189                    0.092                   0.280              3.275            2       True         34
# 10        CatBoost_BAG_L2        -79.146    -81.422  root_mean_squared_error           3.067          3.183   641.191                    0.082                   0.045             99.277            2       True         37
# 11      CatBoost_5_BAG_L2        -79.149    -81.561  root_mean_squared_error           3.065          3.178   593.015                    0.079                   0.040             51.102            2       True         41
# 12      LightGBM_4_BAG_L2        -79.161    -81.651  root_mean_squared_error           3.088          3.200   548.743                    0.102                   0.062              6.830            2       True         30
# 13       XGBoost_5_BAG_L2        -79.166    -81.536  root_mean_squared_error           3.207          3.239   556.116                    0.221                   0.101             14.203            2       True         51
# 14      CatBoost_2_BAG_L2        -79.177    -81.433  root_mean_squared_error           3.069          3.179   621.697                    0.083                   0.041             79.784            2       True         38
# 15         XGBoost_BAG_L2        -79.177    -81.743  root_mean_squared_error           3.198          3.224   559.215                    0.213                   0.086             17.302            2       True         47
# 16    ExtraTrees_4_BAG_L2        -79.183    -81.997  root_mean_squared_error           3.079          3.403   542.568                    0.094                   0.265              0.655            2       True         45
# 17      LightGBM_3_BAG_L2        -79.185    -81.668  root_mean_squared_error           3.085          3.198   550.520                    0.099                   0.060              8.607            2       True         29
# 18      CatBoost_3_BAG_L2        -79.188    -81.478  root_mean_squared_error           3.068          3.182   606.764                    0.082                   0.044             64.850            2       True         39
# 19      LightGBM_2_BAG_L2        -79.213    -81.572  root_mean_squared_error           3.079          3.193   552.643                    0.093                   0.055             10.730            2       True         28
# 20        LightGBM_BAG_L2        -79.216    -81.585  root_mean_squared_error           3.112          3.196   555.140                    0.126                   0.058             13.227            2       True         27
# 21  RandomForest_2_BAG_L2        -79.262    -81.567  root_mean_squared_error           3.079          3.420   545.944                    0.093                   0.282              4.031            2       True         33
# 22       XGBoost_2_BAG_L2        -79.288    -81.572  root_mean_squared_error           3.181          3.219   555.817                    0.195                   0.082             13.903            2       True         48
# 23    RandomForest_BAG_L2        -79.302    -81.459  root_mean_squared_error           3.126          3.407   546.630                    0.140                   0.269              4.717            2       True         32
# 24        CatBoost_BAG_L1        -79.338    -82.106  root_mean_squared_error           0.084          0.050   108.564                    0.084                   0.050            108.564            1       True         11
# 25    WeightedEnsemble_L2        -79.356    -81.942  root_mean_squared_error           0.373          0.457   125.574                    0.012                   0.000              0.049            2       True         26
# 26  RandomForest_5_BAG_L2        -79.366    -82.161  root_mean_squared_error           3.095          3.467   543.719                    0.109                   0.329              1.806            2       True         36
# 27      CatBoost_2_BAG_L1        -79.402    -82.187  root_mean_squared_error           0.080          0.036    89.488                    0.080                   0.036             89.488            1       True         12
# 28       XGBoost_3_BAG_L1        -79.418    -82.328  root_mean_squared_error           0.187          0.075    11.933                    0.187                   0.075             11.933            1       True         23
# 29       XGBoost_2_BAG_L1        -79.432    -82.384  root_mean_squared_error           0.189          0.065    12.266                    0.189                   0.065             12.266            1       True         22
# 30    ExtraTrees_5_BAG_L2        -79.460    -82.289  root_mean_squared_error           3.078          3.396   542.560                    0.092                   0.258              0.647            2       True         46
# 31      CatBoost_4_BAG_L1        -79.483    -82.253  root_mean_squared_error           0.083          0.033    93.643                    0.083                   0.033             93.643            1       True         14
# 32       XGBoost_4_BAG_L1        -79.488    -82.332  root_mean_squared_error           0.191          0.071    11.528                    0.191                   0.071             11.528            1       True         24
# 33    RandomForest_BAG_L1        -79.493    -82.396  root_mean_squared_error           0.103          0.282     0.938                    0.103                   0.282              0.938            1       True          6
# 34       XGBoost_5_BAG_L1        -79.496    -82.410  root_mean_squared_error           0.207          0.080    13.048                    0.207                   0.080             13.048            1       True         25
# 35         XGBoost_BAG_L1        -79.542    -82.514  root_mean_squared_error           0.191          0.069    12.913                    0.191                   0.069             12.913            1       True         21
# 36      CatBoost_3_BAG_L1        -79.560    -82.347  root_mean_squared_error           0.079          0.034    76.651                    0.079                   0.034             76.651            1       True         13
# 37      CatBoost_5_BAG_L1        -79.581    -82.446  root_mean_squared_error           0.255          0.028    59.138                    0.255                   0.028             59.138            1       True         15
# 38  RandomForest_2_BAG_L1        -79.731    -82.528  root_mean_squared_error           0.092          0.250     0.765                    0.092                   0.250              0.765            1       True          7
# 39      LightGBM_4_BAG_L1        -79.732    -82.177  root_mean_squared_error           0.087          0.065     6.364                    0.087                   0.065              6.364            1       True          4
# 40      LightGBM_5_BAG_L1        -79.766    -82.248  root_mean_squared_error           0.101          0.097     6.070                    0.101                   0.097              6.070            1       True          5
# 41      LightGBM_3_BAG_L1        -79.776    -82.261  root_mean_squared_error           0.087          0.060     9.659                    0.087                   0.060              9.659            1       True          3
# 42      LightGBM_2_BAG_L1        -79.809    -82.416  root_mean_squared_error           0.082          0.058    10.529                    0.082                   0.058             10.529            1       True          2
# 43        LightGBM_BAG_L1        -79.921    -82.497  root_mean_squared_error           0.116          0.054    13.340                    0.116                   0.054             13.340            1       True          1
# 44  RandomForest_3_BAG_L1        -80.132    -82.745  root_mean_squared_error           0.112          0.240     0.708                    0.112                   0.240              0.708            1       True          8
# 45      ExtraTrees_BAG_L1        -80.235    -82.674  root_mean_squared_error           0.092          0.222     0.589                    0.092                   0.222              0.589            1       True         16
# 46    ExtraTrees_2_BAG_L1        -80.439    -82.851  root_mean_squared_error           0.096          0.226     0.600                    0.096                   0.226              0.600            1       True         17
# 47  RandomForest_4_BAG_L1        -80.481    -83.044  root_mean_squared_error           0.095          0.212     0.691                    0.095                   0.212              0.691            1       True          9
# 48    ExtraTrees_3_BAG_L1        -80.620    -83.022  root_mean_squared_error           0.095          0.206     0.592                    0.095                   0.206              0.592            1       True         18
# 49  RandomForest_5_BAG_L1        -80.724    -83.304  root_mean_squared_error           0.095          0.195     0.618                    0.095                   0.195              0.618            1       True         10
# 50    ExtraTrees_4_BAG_L1        -80.822    -83.208  root_mean_squared_error           0.092          0.228     0.630                    0.092                   0.228              0.630            1       True         19
# 51    ExtraTrees_5_BAG_L1        -80.992    -83.407  root_mean_squared_error           0.093          0.201     0.647                    0.093                   0.201              0.647            1       True         20
# Stacked overfitting occurred: False.
# Spend 1054 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 34946 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 34946s
# AutoGluon will save models to "AutogluonModels\ag-20240603_094536"
# =================== System Info ===================
# AutoGluon Version:  1.1.1b20240426
# Python Version:     3.10.10
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19045
# CPU Count:          12
# Memory Avail:       6.63 GB / 15.42 GB (43.0%)
# Disk Space Avail:   551.11 GB / 931.51 GB (59.2%)
# ===================================================
# Train Data Rows:    13173
# Train Data Columns: 8
# Label Column:       metastatic_diagnosis_period
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6801.25 MB
# 	Train Data (Original)  Memory Usage: 4.30 MB (0.1% of available memory)
# ...
# 	Ensemble Weights: {'CatBoost_BAG_L1': 0.24, 'LightGBM_4_BAG_L1': 0.2, 'RandomForest_BAG_L1': 0.2, 'CatBoost_3_BAG_L1': 0.16, 'LightGBM_3_BAG_L1': 0.12, 'XGBoost_BAG_L1': 0.04, 'XGBoost_5_BAG_L1': 0.04}
# 	-81.6506	 = Validation score   (-root_mean_squared_error)
# 	0.07s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Included models: ['XGB', 'CAT', 'XT', 'RF', 'GBM'] (Specified by `included_model_types`, all other model types will be skipped)
# Fitting 25 L2 models ...
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 34363.55s of the 34363.52s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-80.9864	 = Validation score   (-root_mean_squared_error)
# 	13.65s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_2_BAG_L2 ... Training model for up to 34349.75s of the 34349.71s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-81.0311	 = Validation score   (-root_mean_squared_error)
# 	13.51s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_3_BAG_L2 ... Training model for up to 34336.07s of the 34336.04s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-81.1759	 = Validation score   (-root_mean_squared_error)
# 	8.85s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_4_BAG_L2 ... Training model for up to 34326.96s of the 34326.92s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	-81.1212	 = Validation score   (-root_mean_squared_error)
# 	8.34s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBM_5_BAG_L2 ... Training model for up to 34318.44s of the 34318.4s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# [1000]	valid_set's rmse: 81.1866
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# [1000]	valid_set's rmse: 80.2364
# 	-81.2314	 = Validation score   (-root_mean_squared_error)
# 	7.51s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForest_BAG_L2 ... Training model for up to 34310.71s of the 34310.68s of remaining time.
# 	-80.998	 = Validation score   (-root_mean_squared_error)
# 	5.72s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: RandomForest_2_BAG_L2 ... Training model for up to 34304.55s of the 34304.52s of remaining time.
# 	-81.1266	 = Validation score   (-root_mean_squared_error)
# 	4.71s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: RandomForest_3_BAG_L2 ... Training model for up to 34299.42s of the 34299.39s of remaining time.
# 	-81.2648	 = Validation score   (-root_mean_squared_error)
# 	3.84s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: RandomForest_4_BAG_L2 ... Training model for up to 34295.13s of the 34295.1s of remaining time.
# 	-81.5873	 = Validation score   (-root_mean_squared_error)
# 	2.94s	 = Training   runtime
# 	0.31s	 = Validation runtime
# Fitting model: RandomForest_5_BAG_L2 ... Training model for up to 34291.77s of the 34291.73s of remaining time.
# 	-81.965	 = Validation score   (-root_mean_squared_error)
# 	2.13s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 34289.21s of the 34289.18s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-80.999	 = Validation score   (-root_mean_squared_error)
# 	94.38s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_2_BAG_L2 ... Training model for up to 34194.72s of the 34194.68s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.0352	 = Validation score   (-root_mean_squared_error)
# 	73.5s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_3_BAG_L2 ... Training model for up to 34121.01s of the 34120.98s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.1033	 = Validation score   (-root_mean_squared_error)
# 	55.42s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_4_BAG_L2 ... Training model for up to 34065.49s of the 34065.46s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.1582	 = Validation score   (-root_mean_squared_error)
# 	46.85s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: CatBoost_5_BAG_L2 ... Training model for up to 34018.55s of the 34018.51s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# 	-81.2386	 = Validation score   (-root_mean_squared_error)
# 	46.41s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTrees_BAG_L2 ... Training model for up to 33972.01s of the 33971.98s of remaining time.
# 	-81.367	 = Validation score   (-root_mean_squared_error)
# 	0.76s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: ExtraTrees_2_BAG_L2 ... Training model for up to 33970.79s of the 33970.76s of remaining time.
# 	-81.4634	 = Validation score   (-root_mean_squared_error)
# 	0.68s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: ExtraTrees_3_BAG_L2 ... Training model for up to 33969.7s of the 33969.67s of remaining time.
# 	-81.563	 = Validation score   (-root_mean_squared_error)
# 	0.71s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: ExtraTrees_4_BAG_L2 ... Training model for up to 33968.56s of the 33968.53s of remaining time.
# 	-81.7005	 = Validation score   (-root_mean_squared_error)
# 	0.69s	 = Training   runtime
# 	0.29s	 = Validation runtime
# Fitting model: ExtraTrees_5_BAG_L2 ... Training model for up to 33967.48s of the 33967.45s of remaining time.
# 	-81.9769	 = Validation score   (-root_mean_squared_error)
# 	0.69s	 = Training   runtime
# 	0.28s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 33966.41s of the 33966.38s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.1659	 = Validation score   (-root_mean_squared_error)
# 	16.36s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost_2_BAG_L2 ... Training model for up to 33949.85s of the 33949.82s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.2347	 = Validation score   (-root_mean_squared_error)
# 	13.77s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_3_BAG_L2 ... Training model for up to 33935.9s of the 33935.87s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.2039	 = Validation score   (-root_mean_squared_error)
# 	12.66s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: XGBoost_4_BAG_L2 ... Training model for up to 33923.05s of the 33923.02s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.3161	 = Validation score   (-root_mean_squared_error)
# 	11.14s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_5_BAG_L2 ... Training model for up to 33911.73s of the 33911.7s of remaining time.
# 	Fitting 5 child models (S1F1 - S1F5) | Fitting with SequentialLocalFoldFittingStrategy
# 	-81.2973	 = Validation score   (-root_mean_squared_error)
# 	13.17s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 3436.36s of the 33898.14s of remaining time.
# 	Ensemble Weights: {'RandomForest_BAG_L2': 0.28, 'LightGBM_2_BAG_L2': 0.24, 'LightGBM_BAG_L2': 0.16, 'CatBoost_BAG_L2': 0.12, 'LightGBM_4_BAG_L2': 0.08, 'XGBoost_BAG_L2': 0.08, 'CatBoost_2_BAG_L2': 0.04}
# 	-80.7192	 = Validation score   (-root_mean_squared_error)
# 	0.05s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 1047.95s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240603_094536")
# CPU times: total: 1h 16min 32s
# Wall time: 35min 3s

# %%
automl.leaderboard()
# Out:
#                     model  score_val              eval_metric  pred_time_val  fit_time  \
# 0     WeightedEnsemble_L3    -80.719  root_mean_squared_error          3.740   802.338
# 1         LightGBM_BAG_L2    -80.986  root_mean_squared_error          3.107   590.471
# 2     RandomForest_BAG_L2    -80.998  root_mean_squared_error          3.355   582.541
# 3         CatBoost_BAG_L2    -80.999  root_mean_squared_error          3.078   671.200
# 4       LightGBM_2_BAG_L2    -81.031  root_mean_squared_error          3.100   590.325
# 5       CatBoost_2_BAG_L2    -81.035  root_mean_squared_error          3.077   650.317
# 6       CatBoost_3_BAG_L2    -81.103  root_mean_squared_error          3.072   632.238
# 7       LightGBM_4_BAG_L2    -81.121  root_mean_squared_error          3.108   585.155
# 8   RandomForest_2_BAG_L2    -81.127  root_mean_squared_error          3.355   581.523
# 9       CatBoost_4_BAG_L2    -81.158  root_mean_squared_error          3.070   623.669
# 10         XGBoost_BAG_L2    -81.166  root_mean_squared_error          3.118   593.178
# 11      LightGBM_3_BAG_L2    -81.176  root_mean_squared_error          3.100   585.671
# 12       XGBoost_3_BAG_L2    -81.204  root_mean_squared_error          3.129   589.480
# 13      LightGBM_5_BAG_L2    -81.231  root_mean_squared_error          3.114   584.326
# 14       XGBoost_2_BAG_L2    -81.235  root_mean_squared_error          3.120   590.587
# 15      CatBoost_5_BAG_L2    -81.239  root_mean_squared_error          3.070   623.229
# 16  RandomForest_3_BAG_L2    -81.265  root_mean_squared_error          3.352   580.660
# 17       XGBoost_5_BAG_L2    -81.297  root_mean_squared_error          3.144   589.986
# 18       XGBoost_4_BAG_L2    -81.316  root_mean_squared_error          3.126   587.955
# 19      ExtraTrees_BAG_L2    -81.367  root_mean_squared_error          3.384   577.575
# 20    ExtraTrees_2_BAG_L2    -81.463  root_mean_squared_error          3.334   577.498
# 21    ExtraTrees_3_BAG_L2    -81.563  root_mean_squared_error          3.356   577.528
# 22  RandomForest_4_BAG_L2    -81.587  root_mean_squared_error          3.342   579.755
# 23    WeightedEnsemble_L2    -81.651  root_mean_squared_error          0.571   244.461
# 24    ExtraTrees_4_BAG_L2    -81.701  root_mean_squared_error          3.323   577.508
# 25        CatBoost_BAG_L1    -81.813  root_mean_squared_error          0.041    96.296
# 26      CatBoost_3_BAG_L1    -81.830  root_mean_squared_error          0.038   106.776
# 27      CatBoost_2_BAG_L1    -81.842  root_mean_squared_error          0.037    99.505
# 28      CatBoost_4_BAG_L1    -81.916  root_mean_squared_error          0.039    83.819
# 29       XGBoost_4_BAG_L1    -81.928  root_mean_squared_error          0.072    11.186
# 30       XGBoost_3_BAG_L1    -81.945  root_mean_squared_error          0.068    11.429
# 31      LightGBM_4_BAG_L1    -81.956  root_mean_squared_error          0.057     5.629
# 32  RandomForest_5_BAG_L2    -81.965  root_mean_squared_error          3.334   578.946
# 33    ExtraTrees_5_BAG_L2    -81.977  root_mean_squared_error          3.314   577.509
# 34       XGBoost_5_BAG_L1    -81.980  root_mean_squared_error          0.085    14.822
# 35    RandomForest_BAG_L1    -81.981  root_mean_squared_error          0.229     0.685
# 36      LightGBM_5_BAG_L1    -81.995  root_mean_squared_error          0.062     4.871
# 37      LightGBM_3_BAG_L1    -82.017  root_mean_squared_error          0.057     7.754
# 38      CatBoost_5_BAG_L1    -82.019  root_mean_squared_error          0.032    81.433
# 39       XGBoost_2_BAG_L1    -82.038  root_mean_squared_error          0.068    11.265
# 40         XGBoost_BAG_L1    -82.140  root_mean_squared_error          0.063    12.434
# 41  RandomForest_2_BAG_L1    -82.146  root_mean_squared_error          0.226     0.657
# 42      LightGBM_2_BAG_L1    -82.185  root_mean_squared_error          0.057    11.073
# 43        LightGBM_BAG_L1    -82.236  root_mean_squared_error          0.054    12.199
# 44      ExtraTrees_BAG_L1    -82.360  root_mean_squared_error          0.229     0.623
# 45  RandomForest_3_BAG_L1    -82.459  root_mean_squared_error          0.225     0.642
# 46    ExtraTrees_2_BAG_L1    -82.537  root_mean_squared_error          0.261     0.632
# 47    ExtraTrees_3_BAG_L1    -82.745  root_mean_squared_error          0.219     0.624
# 48  RandomForest_4_BAG_L1    -82.756  root_mean_squared_error          0.206     0.643
# 49    ExtraTrees_4_BAG_L1    -82.934  root_mean_squared_error          0.210     0.602
# 50  RandomForest_5_BAG_L1    -83.031  root_mean_squared_error          0.198     0.608
# 51    ExtraTrees_5_BAG_L1    -83.136  root_mean_squared_error          0.201     0.610
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0                    0.000              0.051            3       True         52
# 1                    0.073             13.654            2       True         27
# 2                    0.321              5.724            2       True         32
# 3                    0.045             94.383            2       True         37
# 4                    0.066             13.508            2       True         28
# 5                    0.043             73.500            2       True         38
# 6                    0.039             55.421            2       True         39
# 7                    0.074              8.338            2       True         30
# 8                    0.321              4.706            2       True         33
# 9                    0.036             46.852            2       True         40
# 10                   0.084             16.361            2       True         47
# 11                   0.067              8.854            2       True         29
# 12                   0.095             12.663            2       True         49
# 13                   0.080              7.509            2       True         31
# 14                   0.086             13.770            2       True         48
# 15                   0.037             46.413            2       True         41
# 16                   0.318              3.843            2       True         34
# 17                   0.110             13.169            2       True         51
# 18                   0.093             11.139            2       True         50
# 19                   0.351              0.758            2       True         42
# 20                   0.300              0.681            2       True         43
# 21                   0.322              0.711            2       True         44
# 22                   0.308              2.938            2       True         35
# 23                   0.001              0.066            2       True         26
# 24                   0.290              0.691            2       True         45
# 25                   0.041             96.296            1       True         11
# 26                   0.038            106.776            1       True         13
# 27                   0.037             99.505            1       True         12
# 28                   0.039             83.819            1       True         14
# 29                   0.072             11.186            1       True         24
# 30                   0.068             11.429            1       True         23
# 31                   0.057              5.629            1       True          4
# 32                   0.300              2.129            2       True         36
# 33                   0.280              0.692            2       True         46
# 34                   0.085             14.822            1       True         25
# 35                   0.229              0.685            1       True          6
# 36                   0.062              4.871            1       True          5
# 37                   0.057              7.754            1       True          3
# 38                   0.032             81.433            1       True         15
# 39                   0.068             11.265            1       True         22
# 40                   0.063             12.434            1       True         21
# 41                   0.226              0.657            1       True          7
# 42                   0.057             11.073            1       True          2
# 43                   0.054             12.199            1       True          1
# 44                   0.229              0.623            1       True         16
# 45                   0.225              0.642            1       True          8
# 46                   0.261              0.632            1       True         17
# 47                   0.219              0.624            1       True         18
# 48                   0.206              0.643            1       True          9
# 49                   0.210              0.602            1       True         19
# 50                   0.198              0.608            1       True         10
# 51                   0.201              0.610            1       True         20

# %%
# Tahminleri bir liste içinde saklıyoruz
models = ['RandomForest_BAG_L2', 'CatBoost_BAG_L2']
weights = [0.5, 0.5]

# Tahminleri hesaplıyoruz ve ağırlıklandırıyoruz
predictions = sum(weight * automl.predict(test, model=model) for model, weight in zip(models, weights))

# %%
submission["metastatic_diagnosis_period"] = predictions

submission
# Out:
#       patient_id  metastatic_diagnosis_period
# 0         730681                      220.000
# 1         334212                       57.000
# 2         571362                      204.000
# 3         907331                      218.000
# 4         208382                       45.000
# ...          ...                          ...
# 5641      649011                       43.000
# 5642      869024                       74.000
# 5643      304800                      230.000
# 5644      267406                       67.000
# 5645      873886                       51.000
#
# [5646 rows x 2 columns]

# %%
submission.to_csv('submission.csv', index=False)
